# %% [markdown]
# <nav class="navbar navbar-default">
#   <div class="container-fluid">
#     <div class="navbar-header">
#       <a class="navbar-brand" href="_Oving10.ipynb">Øving 10</a>
#     </div>
#     <ul class="nav navbar-nav">
#     <li class="active"><a href="Rekursjon.ipynb">Rekursjon (Obligatorisk TDT4109)</a></li>
#     <li ><a href="Matplotlib.ipynb">Matplotlib (Obligatorisk TDT4110)</a></li>
#     <li ><a href="Eksamen%202012.ipynb">Eksamen Python 2012</a></li>
#     <li ><a href="Sudoku.ipynb">Sudoku</a></li>
#     <li ><a href="numpy-arrays%20og%20matplotlib.ipynb">Numpy-arrays og matplotlib (TDT4110)</a></li>
#     <li ><a href="Bokanalyse%20med%20plotting.ipynb">Bokanalyse med plotting (TDT4110)</a></li>
#     <li ><a href="Sjakk.ipynb">Sjakk</a></li>
#     </ul>
#   </div>
# </nav>
#
#
# # Rekursjon
#
# **Læringsmål:**
#
# * Rekursjon
# * Algoritmer
#
# **Starting Out with Python:**
#
# * Kap. 12: Recursion

# %% [markdown]
# ### Rekursjon, hva er det?

# %% [markdown]
# Dersom en funksjon kaller på seg selv kaller vi dette for rekursjon. Rekursjon er et viktig konsept innenfor datateknologi, og det er en mye brukt teknikk for å løse problemer som kan deles opp i mindre tilsvarende subproblemer. For eksempel bygger en rekke søkealgoritmer på konseptet rekursjon.
#
# ![img](./../../Resources/Images/fixing_problems.webp)
#
# La oss begynne å se på en veldig enkel funksjon som benytter seg av rekursjon, som nevnt betyr dette bare at funksjonen kaller seg selv.
#
# **Eksempel:**

# %%
def teller(nummer=0):
    print("Nå har vi kommet til: ", nummer)
    teller(nummer + 1)
    
teller()
# Out:
# Nå har vi kommet til:  0
# Nå har vi kommet til:  1
# Nå har vi kommet til:  2
# Nå har vi kommet til:  3
# Nå har vi kommet til:  4
# Nå har vi kommet til:  5
# Nå har vi kommet til:  6
# Nå har vi kommet til:  7
# Nå har vi kommet til:  8
# Nå har vi kommet til:  9
# Nå har vi kommet til:  10
# Nå har vi kommet til:  11
# Nå har vi kommet til:  12
# Nå har vi kommet til:  13
# Nå har vi kommet til:  14
# Nå har vi kommet til:  15
# Nå har vi kommet til:  16
# Nå har vi kommet til:  17
# Nå har vi kommet til:  18
# Nå har vi kommet til:  19
# Nå har vi kommet til:  20
# Nå har vi kommet til:  21
# Nå har vi kommet til:  22
# Nå har vi kommet til:  23
# Nå har vi kommet til:  24
# Nå har vi kommet til:  25
# Nå har vi kommet til:  26
# Nå har vi kommet til:  27
# Nå har vi kommet til:  28
# Nå har vi kommet til:  29
# Nå har vi kommet til:  30
# Nå har vi kommet til:  31
# Nå har vi kommet til:  32
# Nå har vi kommet til:  33
# Nå har vi kommet til:  34
# Nå har vi kommet til:  35
# Nå har vi kommet til:  36
# Nå har vi kommet til:  37
# Nå har vi kommet til:  38
# Nå har vi kommet til:  39
# Nå har vi kommet til:  40
# Nå har vi kommet til:  41
# Nå har vi kommet til:  42
# Nå har vi kommet til:  43
# Nå har vi kommet til:  44
# Nå har vi kommet til:  45
# Nå har vi kommet til:  46
# Nå har vi kommet til:  47
# Nå har vi kommet til:  48
# Nå har vi kommet til:  49
# Nå har vi kommet til:  50
# Nå har vi kommet til:  51
# Nå har vi kommet til:  52
# Nå har vi kommet til:  53
# Nå har vi kommet til:  54
# Nå har vi kommet til:  55
# Nå har vi kommet til:  56
# Nå har vi kommet til:  57
# Nå har vi kommet til:  58
# Nå har vi kommet til:  59
# Nå har vi kommet til:  60
# Nå har vi kommet til:  61
# Nå har vi kommet til:  62
# Nå har vi kommet til:  63
# Nå har vi kommet til:  64
# Nå har vi kommet til:  65
# Nå har vi kommet til:  66
# Nå har vi kommet til:  67
# Nå har vi kommet til:  68
# Nå har vi kommet til:  69
# Nå har vi kommet til:  70
# Nå har vi kommet til:  71
# Nå har vi kommet til:  72
# Nå har vi kommet til:  73
# Nå har vi kommet til:  74
# Nå har vi kommet til:  75
# Nå har vi kommet til:  76
# Nå har vi kommet til:  77
# Nå har vi kommet til:  78
# Nå har vi kommet til:  79
# Nå har vi kommet til:  80
# Nå har vi kommet til:  81
# Nå har vi kommet til:  82
# Nå har vi kommet til:  83
# Nå har vi kommet til:  84
# Nå har vi kommet til:  85
# Nå har vi kommet til:  86
# Nå har vi kommet til:  87
# Nå har vi kommet til:  88
# Nå har vi kommet til:  89
# Nå har vi kommet til:  90
# Nå har vi kommet til:  91
# Nå har vi kommet til:  92
# Nå har vi kommet til:  93
# Nå har vi kommet til:  94
# Nå har vi kommet til:  95
# Nå har vi kommet til:  96
# Nå har vi kommet til:  97
# Nå har vi kommet til:  98
# Nå har vi kommet til:  99
# Nå har vi kommet til:  100
# Nå har vi kommet til:  101
# Nå har vi kommet til:  102
# Nå har vi kommet til:  103
# Nå har vi kommet til:  104
# Nå har vi kommet til:  105
# Nå har vi kommet til:  106
# Nå har vi kommet til:  107
# Nå har vi kommet til:  108
# Nå har vi kommet til:  109
# Nå har vi kommet til:  110
# Nå har vi kommet til:  111
# Nå har vi kommet til:  112
# Nå har vi kommet til:  113
# Nå har vi kommet til:  114
# Nå har vi kommet til:  115
# Nå har vi kommet til:  116
# Nå har vi kommet til:  117
# Nå har vi kommet til:  118
# Nå har vi kommet til:  119
# Nå har vi kommet til:  120
# Nå har vi kommet til:  121
# Nå har vi kommet til:  122
# Nå har vi kommet til:  123
# Nå har vi kommet til:  124
# Nå har vi kommet til:  125
# Nå har vi kommet til:  126
# Nå har vi kommet til:  127
# Nå har vi kommet til:  128
# Nå har vi kommet til:  129
# Nå har vi kommet til:  130
# Nå har vi kommet til:  131
# Nå har vi kommet til:  132
# Nå har vi kommet til:  133
# Nå har vi kommet til:  134
# Nå har vi kommet til:  135
# Nå har vi kommet til:  136
# Nå har vi kommet til:  137
# Nå har vi kommet til:  138
# Nå har vi kommet til:  139
# Nå har vi kommet til:  140
# Nå har vi kommet til:  141
# Nå har vi kommet til:  142
# Nå har vi kommet til:  143
# Nå har vi kommet til:  144
# Nå har vi kommet til:  145
# Nå har vi kommet til:  146
# Nå har vi kommet til:  147
# Nå har vi kommet til:  148
# Nå har vi kommet til:  149
# Nå har vi kommet til:  150
# Nå har vi kommet til:  151
# Nå har vi kommet til:  152
# Nå har vi kommet til:  153
# Nå har vi kommet til:  154
# Nå har vi kommet til:  155
# Nå har vi kommet til:  156
# Nå har vi kommet til:  157
# Nå har vi kommet til:  158
# Nå har vi kommet til:  159
# Nå har vi kommet til:  160
# Nå har vi kommet til:  161
# Nå har vi kommet til:  162
# Nå har vi kommet til:  163
# Nå har vi kommet til:  164
# Nå har vi kommet til:  165
# Nå har vi kommet til:  166
# Nå har vi kommet til:  167
# Nå har vi kommet til:  168
# Nå har vi kommet til:  169
# Nå har vi kommet til:  170
# Nå har vi kommet til:  171
# Nå har vi kommet til:  172
# Nå har vi kommet til:  173
# Nå har vi kommet til:  174
# Nå har vi kommet til:  175
# Nå har vi kommet til:  176
# Nå har vi kommet til:  177
# Nå har vi kommet til:  178
# Nå har vi kommet til:  179
# Nå har vi kommet til:  180
# Nå har vi kommet til:  181
# Nå har vi kommet til:  182
# Nå har vi kommet til:  183
# Nå har vi kommet til:  184
# Nå har vi kommet til:  185
# Nå har vi kommet til:  186
# Nå har vi kommet til:  187
# Nå har vi kommet til:  188
# Nå har vi kommet til:  189
# Nå har vi kommet til:  190
# Nå har vi kommet til:  191
# Nå har vi kommet til:  192
# Nå har vi kommet til:  193
# Nå har vi kommet til:  194
# Nå har vi kommet til:  195
# Nå har vi kommet til:  196
# Nå har vi kommet til:  197
# Nå har vi kommet til:  198
# Nå har vi kommet til:  199
# Nå har vi kommet til:  200
# Nå har vi kommet til:  201
# Nå har vi kommet til:  202
# Nå har vi kommet til:  203
# Nå har vi kommet til:  204
# Nå har vi kommet til:  205
# Nå har vi kommet til:  206
# Nå har vi kommet til:  207
# Nå har vi kommet til:  208
# Nå har vi kommet til:  209
# Nå har vi kommet til:  210
# Nå har vi kommet til:  211
# Nå har vi kommet til:  212
# Nå har vi kommet til:  213
# Nå har vi kommet til:  214
# Nå har vi kommet til:  215
# Nå har vi kommet til:  216
# Nå har vi kommet til:  217
# Nå har vi kommet til:  218
# Nå har vi kommet til:  219
# Nå har vi kommet til:  220
# Nå har vi kommet til:  221
# Nå har vi kommet til:  222
# Nå har vi kommet til:  223
# Nå har vi kommet til:  224
# Nå har vi kommet til:  225
# Nå har vi kommet til:  226
# Nå har vi kommet til:  227
# Nå har vi kommet til:  228
# Nå har vi kommet til:  229
# Nå har vi kommet til:  230
# Nå har vi kommet til:  231
# Nå har vi kommet til:  232
# Nå har vi kommet til:  233
# Nå har vi kommet til:  234
# Nå har vi kommet til:  235
# Nå har vi kommet til:  236
# Nå har vi kommet til:  237
# Nå har vi kommet til:  238
# Nå har vi kommet til:  239
# Nå har vi kommet til:  240
# Nå har vi kommet til:  241
# Nå har vi kommet til:  242
# Nå har vi kommet til:  243
# Nå har vi kommet til:  244
# Nå har vi kommet til:  245
# Nå har vi kommet til:  246
# Nå har vi kommet til:  247
# Nå har vi kommet til:  248
# Nå har vi kommet til:  249
# Nå har vi kommet til:  250
# Nå har vi kommet til:  251
# Nå har vi kommet til:  252
# Nå har vi kommet til:  253
# Nå har vi kommet til:  254
# Nå har vi kommet til:  255
# Nå har vi kommet til:  256
# Nå har vi kommet til:  257
# Nå har vi kommet til:  258
# Nå har vi kommet til:  259
# Nå har vi kommet til:  260
# Nå har vi kommet til:  261
# Nå har vi kommet til:  262
# Nå har vi kommet til:  263
# Nå har vi kommet til:  264
# Nå har vi kommet til:  265
# Nå har vi kommet til:  266
# Nå har vi kommet til:  267
# Nå har vi kommet til:  268
# Nå har vi kommet til:  269
# Nå har vi kommet til:  270
# Nå har vi kommet til:  271
# Nå har vi kommet til:  272
# Nå har vi kommet til:  273
# Nå har vi kommet til:  274
# Nå har vi kommet til:  275
# Nå har vi kommet til:  276
# Nå har vi kommet til:  277
# Nå har vi kommet til:  278
# Nå har vi kommet til:  279
# Nå har vi kommet til:  280
# Nå har vi kommet til:  281
# Nå har vi kommet til:  282
# Nå har vi kommet til:  283
# Nå har vi kommet til:  284
# Nå har vi kommet til:  285
# Nå har vi kommet til:  286
# Nå har vi kommet til:  287
# Nå har vi kommet til:  288
# Nå har vi kommet til:  289
# Nå har vi kommet til:  290
# Nå har vi kommet til:  291
# Nå har vi kommet til:  292
# Nå har vi kommet til:  293
# Nå har vi kommet til:  294
# Nå har vi kommet til:  295
# Nå har vi kommet til:  296
# Nå har vi kommet til:  297
# Nå har vi kommet til:  298
# Nå har vi kommet til:  299
# Nå har vi kommet til:  300
# Nå har vi kommet til:  301
# Nå har vi kommet til:  302
# Nå har vi kommet til:  303
# Nå har vi kommet til:  304
# Nå har vi kommet til:  305
# Nå har vi kommet til:  306
# Nå har vi kommet til:  307
# Nå har vi kommet til:  308
# Nå har vi kommet til:  309
# Nå har vi kommet til:  310
# Nå har vi kommet til:  311
# Nå har vi kommet til:  312
# Nå har vi kommet til:  313
# Nå har vi kommet til:  314
# Nå har vi kommet til:  315
# Nå har vi kommet til:  316
# Nå har vi kommet til:  317
# Nå har vi kommet til:  318
# Nå har vi kommet til:  319
# Nå har vi kommet til:  320
# Nå har vi kommet til:  321
# Nå har vi kommet til:  322
# Nå har vi kommet til:  323
# Nå har vi kommet til:  324
# Nå har vi kommet til:  325
# Nå har vi kommet til:  326
# Nå har vi kommet til:  327
# Nå har vi kommet til:  328
# Nå har vi kommet til:  329
# Nå har vi kommet til:  330
# Nå har vi kommet til:  331
# Nå har vi kommet til:  332
# Nå har vi kommet til:  333
# Nå har vi kommet til:  334
# Nå har vi kommet til:  335
# Nå har vi kommet til:  336
# Nå har vi kommet til:  337
# Nå har vi kommet til:  338
# Nå har vi kommet til:  339
# Nå har vi kommet til:  340
# Nå har vi kommet til:  341
# Nå har vi kommet til:  342
# Nå har vi kommet til:  343
# Nå har vi kommet til:  344
# Nå har vi kommet til:  345
# Nå har vi kommet til:  346
# Nå har vi kommet til:  347
# Nå har vi kommet til:  348
# Nå har vi kommet til:  349
# Nå har vi kommet til:  350
# Nå har vi kommet til:  351
# Nå har vi kommet til:  352
# Nå har vi kommet til:  353
# Nå har vi kommet til:  354
# Nå har vi kommet til:  355
# Nå har vi kommet til:  356
# Nå har vi kommet til:  357
# Nå har vi kommet til:  358
# Nå har vi kommet til:  359
# Nå har vi kommet til:  360
# Nå har vi kommet til:  361
# Nå har vi kommet til:  362
# Nå har vi kommet til:  363
# Nå har vi kommet til:  364
# Nå har vi kommet til:  365
# Nå har vi kommet til:  366
# Nå har vi kommet til:  367
# Nå har vi kommet til:  368
# Nå har vi kommet til:  369
# Nå har vi kommet til:  370
# Nå har vi kommet til:  371
# Nå har vi kommet til:  372
# Nå har vi kommet til:  373
# Nå har vi kommet til:  374
# Nå har vi kommet til:  375
# Nå har vi kommet til:  376
# Nå har vi kommet til:  377
# Nå har vi kommet til:  378
# Nå har vi kommet til:  379
# Nå har vi kommet til:  380
# Nå har vi kommet til:  381
# Nå har vi kommet til:  382
# Nå har vi kommet til:  383
# Nå har vi kommet til:  384
# Nå har vi kommet til:  385
# Nå har vi kommet til:  386
# Nå har vi kommet til:  387
# Nå har vi kommet til:  388
# Nå har vi kommet til:  389
# Nå har vi kommet til:  390
# Nå har vi kommet til:  391
# Nå har vi kommet til:  392
# Nå har vi kommet til:  393
# Nå har vi kommet til:  394
# Nå har vi kommet til:  395
# Nå har vi kommet til:  396
# Nå har vi kommet til:  397
# Nå har vi kommet til:  398
# Nå har vi kommet til:  399
# Nå har vi kommet til:  400
# Nå har vi kommet til:  401
# Nå har vi kommet til:  402
# Nå har vi kommet til:  403
# Nå har vi kommet til:  404
# Nå har vi kommet til:  405
# Nå har vi kommet til:  406
# Nå har vi kommet til:  407
# Nå har vi kommet til:  408
# Nå har vi kommet til:  409
# Nå har vi kommet til:  410
# Nå har vi kommet til:  411
# Nå har vi kommet til:  412
# Nå har vi kommet til:  413
# Nå har vi kommet til:  414
# Nå har vi kommet til:  415
# Nå har vi kommet til:  416
# Nå har vi kommet til:  417
# Nå har vi kommet til:  418
# Nå har vi kommet til:  419
# Nå har vi kommet til:  420
# Nå har vi kommet til:  421
# Nå har vi kommet til:  422
# Nå har vi kommet til:  423
# Nå har vi kommet til:  424
# Nå har vi kommet til:  425
# Nå har vi kommet til:  426
# Nå har vi kommet til:  427
# Nå har vi kommet til:  428
# Nå har vi kommet til:  429
# Nå har vi kommet til:  430
# Nå har vi kommet til:  431
# Nå har vi kommet til:  432
# Nå har vi kommet til:  433
# Nå har vi kommet til:  434
# Nå har vi kommet til:  435
# Nå har vi kommet til:  436
# Nå har vi kommet til:  437
# Nå har vi kommet til:  438
# Nå har vi kommet til:  439
# Nå har vi kommet til:  440
# Nå har vi kommet til:  441
# Nå har vi kommet til:  442
# Nå har vi kommet til:  443
# Nå har vi kommet til:  444
# Nå har vi kommet til:  445
# Nå har vi kommet til:  446
# Nå har vi kommet til:  447
# Nå har vi kommet til:  448
# Nå har vi kommet til:  449
# Nå har vi kommet til:  450
# Nå har vi kommet til:  451
# Nå har vi kommet til:  452
# Nå har vi kommet til:  453
# Nå har vi kommet til:  454
# Nå har vi kommet til:  455
# Nå har vi kommet til:  456
# Nå har vi kommet til:  457
# Nå har vi kommet til:  458
# Nå har vi kommet til:  459
# Nå har vi kommet til:  460
# Nå har vi kommet til:  461
# Nå har vi kommet til:  462
# Nå har vi kommet til:  463
# Nå har vi kommet til:  464
# Nå har vi kommet til:  465
# Nå har vi kommet til:  466
# Nå har vi kommet til:  467
# Nå har vi kommet til:  468
# Nå har vi kommet til:  469
# Nå har vi kommet til:  470
# Nå har vi kommet til:  471
# Nå har vi kommet til:  472
# Nå har vi kommet til:  473
# Nå har vi kommet til:  474
# Nå har vi kommet til:  475
# Nå har vi kommet til:  476
# Nå har vi kommet til:  477
# Nå har vi kommet til:  478
# Nå har vi kommet til:  479
# Nå har vi kommet til:  480
# Nå har vi kommet til:  481
# Nå har vi kommet til:  482
# Nå har vi kommet til:  483
# Nå har vi kommet til:  484
# Nå har vi kommet til:  485
# Nå har vi kommet til:  486
# Nå har vi kommet til:  487
# Nå har vi kommet til:  488
# Nå har vi kommet til:  489
# Nå har vi kommet til:  490
# Nå har vi kommet til:  491
# Nå har vi kommet til:  492
# Nå har vi kommet til:  493
# Nå har vi kommet til:  494
# Nå har vi kommet til:  495
# Nå har vi kommet til:  496
# Nå har vi kommet til:  497
# Nå har vi kommet til:  498
# Nå har vi kommet til:  499
# Nå har vi kommet til:  500
# Nå har vi kommet til:  501
# Nå har vi kommet til:  502
# Nå har vi kommet til:  503
# Nå har vi kommet til:  504
# Nå har vi kommet til:  505
# Nå har vi kommet til:  506
# Nå har vi kommet til:  507
# Nå har vi kommet til:  508
# Nå har vi kommet til:  509
# Nå har vi kommet til:  510
# Nå har vi kommet til:  511
# Nå har vi kommet til:  512
# Nå har vi kommet til:  513
# Nå har vi kommet til:  514
# Nå har vi kommet til:  515
# Nå har vi kommet til:  516
# Nå har vi kommet til:  517
# Nå har vi kommet til:  518
# Nå har vi kommet til:  519
# Nå har vi kommet til:  520
# Nå har vi kommet til:  521
# Nå har vi kommet til:  522
# Nå har vi kommet til:  523
# Nå har vi kommet til:  524
# Nå har vi kommet til:  525
# Nå har vi kommet til:  526
# Nå har vi kommet til:  527
# Nå har vi kommet til:  528
# Nå har vi kommet til:  529
# Nå har vi kommet til:  530
# Nå har vi kommet til:  531
# Nå har vi kommet til:  532
# Nå har vi kommet til:  533
# Nå har vi kommet til:  534
# Nå har vi kommet til:  535
# Nå har vi kommet til:  536
# Nå har vi kommet til:  537
# Nå har vi kommet til:  538
# Nå har vi kommet til:  539
# Nå har vi kommet til:  540
# Nå har vi kommet til:  541
# Nå har vi kommet til:  542
# Nå har vi kommet til:  543
# Nå har vi kommet til:  544
# Nå har vi kommet til:  545
# Nå har vi kommet til:  546
# Nå har vi kommet til:  547
# Nå har vi kommet til:  548
# Nå har vi kommet til:  549
# Nå har vi kommet til:  550
# Nå har vi kommet til:  551
# Nå har vi kommet til:  552
# Nå har vi kommet til:  553
# Nå har vi kommet til:  554
# Nå har vi kommet til:  555
# Nå har vi kommet til:  556
# Nå har vi kommet til:  557
# Nå har vi kommet til:  558
# Nå har vi kommet til:  559
# Nå har vi kommet til:  560
# Nå har vi kommet til:  561
# Nå har vi kommet til:  562
# Nå har vi kommet til:  563
# Nå har vi kommet til:  564
# Nå har vi kommet til:  565
# Nå har vi kommet til:  566
# Nå har vi kommet til:  567
# Nå har vi kommet til:  568
# Nå har vi kommet til:  569
# Nå har vi kommet til:  570
# Nå har vi kommet til:  571
# Nå har vi kommet til:  572
# Nå har vi kommet til:  573
# Nå har vi kommet til:  574
# Nå har vi kommet til:  575
# Nå har vi kommet til:  576
# Nå har vi kommet til:  577
# Nå har vi kommet til:  578
# Nå har vi kommet til:  579
# Nå har vi kommet til:  580
# Nå har vi kommet til:  581
# Nå har vi kommet til:  582
# Nå har vi kommet til:  583
# Nå har vi kommet til:  584
# Nå har vi kommet til:  585
# Nå har vi kommet til:  586
# Nå har vi kommet til:  587
# Nå har vi kommet til:  588
# Nå har vi kommet til:  589
# Nå har vi kommet til:  590
# Nå har vi kommet til:  591
# Nå har vi kommet til:  592
# Nå har vi kommet til:  593
# Nå har vi kommet til:  594
# Nå har vi kommet til:  595
# Nå har vi kommet til:  596
# Nå har vi kommet til:  597
# Nå har vi kommet til:  598
# Nå har vi kommet til:  599
# Nå har vi kommet til:  600
# Nå har vi kommet til:  601
# Nå har vi kommet til:  602
# Nå har vi kommet til:  603
# Nå har vi kommet til:  604
# Nå har vi kommet til:  605
# Nå har vi kommet til:  606
# Nå har vi kommet til:  607
# Nå har vi kommet til:  608
# Nå har vi kommet til:  609
# Nå har vi kommet til:  610
# Nå har vi kommet til:  611
# Nå har vi kommet til:  612
# Nå har vi kommet til:  613
# Nå har vi kommet til:  614
# Nå har vi kommet til:  615
# Nå har vi kommet til:  616
# Nå har vi kommet til:  617
# Nå har vi kommet til:  618
# Nå har vi kommet til:  619
# Nå har vi kommet til:  620
# Nå har vi kommet til:  621
# Nå har vi kommet til:  622
# Nå har vi kommet til:  623
# Nå har vi kommet til:  624
# Nå har vi kommet til:  625
# Nå har vi kommet til:  626
# Nå har vi kommet til:  627
# Nå har vi kommet til:  628
# Nå har vi kommet til:  629
# Nå har vi kommet til:  630
# Nå har vi kommet til:  631
# Nå har vi kommet til:  632
# Nå har vi kommet til:  633
# Nå har vi kommet til:  634
# Nå har vi kommet til:  635
# Nå har vi kommet til:  636
# Nå har vi kommet til:  637
# Nå har vi kommet til:  638
# Nå har vi kommet til:  639
# Nå har vi kommet til:  640
# Nå har vi kommet til:  641
# Nå har vi kommet til:  642
# Nå har vi kommet til:  643
# Nå har vi kommet til:  644
# Nå har vi kommet til:  645
# Nå har vi kommet til:  646
# Nå har vi kommet til:  647
# Nå har vi kommet til:  648
# Nå har vi kommet til:  649
# Nå har vi kommet til:  650
# Nå har vi kommet til:  651
# Nå har vi kommet til:  652
# Nå har vi kommet til:  653
# Nå har vi kommet til:  654
# Nå har vi kommet til:  655
# Nå har vi kommet til:  656
# Nå har vi kommet til:  657
# Nå har vi kommet til:  658
# Nå har vi kommet til:  659
# Nå har vi kommet til:  660
# Nå har vi kommet til:  661
# Nå har vi kommet til:  662
# Nå har vi kommet til:  663
# Nå har vi kommet til:  664
# Nå har vi kommet til:  665
# Nå har vi kommet til:  666
# Nå har vi kommet til:  667
# Nå har vi kommet til:  668
# Nå har vi kommet til:  669
# Nå har vi kommet til:  670
# Nå har vi kommet til:  671
# Nå har vi kommet til:  672
# Nå har vi kommet til:  673
# Nå har vi kommet til:  674
# Nå har vi kommet til:  675
# Nå har vi kommet til:  676
# Nå har vi kommet til:  677
# Nå har vi kommet til:  678
# Nå har vi kommet til:  679
# Nå har vi kommet til:  680
# Nå har vi kommet til:  681
# Nå har vi kommet til:  682
# Nå har vi kommet til:  683
# Nå har vi kommet til:  684
# Nå har vi kommet til:  685
# Nå har vi kommet til:  686
# Nå har vi kommet til:  687
# Nå har vi kommet til:  688
# Nå har vi kommet til:  689
# Nå har vi kommet til:  690
# Nå har vi kommet til:  691
# Nå har vi kommet til:  692
# Nå har vi kommet til:  693
# Nå har vi kommet til:  694
# Nå har vi kommet til:  695
# Nå har vi kommet til:  696
# Nå har vi kommet til:  697
# Nå har vi kommet til:  698
# Nå har vi kommet til:  699
# Nå har vi kommet til:  700
# Nå har vi kommet til:  701
# Nå har vi kommet til:  702
# Nå har vi kommet til:  703
# Nå har vi kommet til:  704
# Nå har vi kommet til:  705
# Nå har vi kommet til:  706
# Nå har vi kommet til:  707
# Nå har vi kommet til:  708
# Nå har vi kommet til:  709
# Nå har vi kommet til:  710
# Nå har vi kommet til:  711
# Nå har vi kommet til:  712
# Nå har vi kommet til:  713
# Nå har vi kommet til:  714
# Nå har vi kommet til:  715
# Nå har vi kommet til:  716
# Nå har vi kommet til:  717
# Nå har vi kommet til:  718
# Nå har vi kommet til:  719
# Nå har vi kommet til:  720
# Nå har vi kommet til:  721
# Nå har vi kommet til:  722
# Nå har vi kommet til:  723
# Nå har vi kommet til:  724
# Nå har vi kommet til:  725
# Nå har vi kommet til:  726
# Nå har vi kommet til:  727
# Nå har vi kommet til:  728
# Nå har vi kommet til:  729
# Nå har vi kommet til:  730
# Nå har vi kommet til:  731
# Nå har vi kommet til:  732
# Nå har vi kommet til:  733
# Nå har vi kommet til:  734
# Nå har vi kommet til:  735
# Nå har vi kommet til:  736
# Nå har vi kommet til:  737
# Nå har vi kommet til:  738
# Nå har vi kommet til:  739
# Nå har vi kommet til:  740
# Nå har vi kommet til:  741
# Nå har vi kommet til:  742
# Nå har vi kommet til:  743
# Nå har vi kommet til:  744
# Nå har vi kommet til:  745
# Nå har vi kommet til:  746
# Nå har vi kommet til:  747
# Nå har vi kommet til:  748
# Nå har vi kommet til:  749
# Nå har vi kommet til:  750
# Nå har vi kommet til:  751
# Nå har vi kommet til:  752
# Nå har vi kommet til:  753
# Nå har vi kommet til:  754
# Nå har vi kommet til:  755
# Nå har vi kommet til:  756
# Nå har vi kommet til:  757
# Nå har vi kommet til:  758
# Nå har vi kommet til:  759
# Nå har vi kommet til:  760
# Nå har vi kommet til:  761
# Nå har vi kommet til:  762
# Nå har vi kommet til:  763
# Nå har vi kommet til:  764
# Nå har vi kommet til:  765
# Nå har vi kommet til:  766
# Nå har vi kommet til:  767
# Nå har vi kommet til:  768
# Nå har vi kommet til:  769
# Nå har vi kommet til:  770
# Nå har vi kommet til:  771
# Nå har vi kommet til:  772
# Nå har vi kommet til:  773
# Nå har vi kommet til:  774
# Nå har vi kommet til:  775
# Nå har vi kommet til:  776
# Nå har vi kommet til:  777
# Nå har vi kommet til:  778
# Nå har vi kommet til:  779
# Nå har vi kommet til:  780
# Nå har vi kommet til:  781
# Nå har vi kommet til:  782
# Nå har vi kommet til:  783
# Nå har vi kommet til:  784
# Nå har vi kommet til:  785
# Nå har vi kommet til:  786
# Nå har vi kommet til:  787
# Nå har vi kommet til:  788
# Nå har vi kommet til:  789
# Nå har vi kommet til:  790
# Nå har vi kommet til:  791
# Nå har vi kommet til:  792
# Nå har vi kommet til:  793
# Nå har vi kommet til:  794
# Nå har vi kommet til:  795
# Nå har vi kommet til:  796
# Nå har vi kommet til:  797
# Nå har vi kommet til:  798
# Nå har vi kommet til:  799
# Nå har vi kommet til:  800
# Nå har vi kommet til:  801
# Nå har vi kommet til:  802
# Nå har vi kommet til:  803
# Nå har vi kommet til:  804
# Nå har vi kommet til:  805
# Nå har vi kommet til:  806
# Nå har vi kommet til:  807
# Nå har vi kommet til:  808
# Nå har vi kommet til:  809
# Nå har vi kommet til:  810
# Nå har vi kommet til:  811
# Nå har vi kommet til:  812
# Nå har vi kommet til:  813
# Nå har vi kommet til:  814
# Nå har vi kommet til:  815
# Nå har vi kommet til:  816
# Nå har vi kommet til:  817
# Nå har vi kommet til:  818
# Nå har vi kommet til:  819
# Nå har vi kommet til:  820
# Nå har vi kommet til:  821
# Nå har vi kommet til:  822
# Nå har vi kommet til:  823
# Nå har vi kommet til:  824
# Nå har vi kommet til:  825
# Nå har vi kommet til:  826
# Nå har vi kommet til:  827
# Nå har vi kommet til:  828
# Nå har vi kommet til:  829
# Nå har vi kommet til:  830
# Nå har vi kommet til:  831
# Nå har vi kommet til:  832
# Nå har vi kommet til:  833
# Nå har vi kommet til:  834
# Nå har vi kommet til:  835
# Nå har vi kommet til:  836
# Nå har vi kommet til:  837
# Nå har vi kommet til:  838
# Nå har vi kommet til:  839
# Nå har vi kommet til:  840
# Nå har vi kommet til:  841
# Nå har vi kommet til:  842
# Nå har vi kommet til:  843
# Nå har vi kommet til:  844
# Nå har vi kommet til:  845
# Nå har vi kommet til:  846
# Nå har vi kommet til:  847
# Nå har vi kommet til:  848
# Nå har vi kommet til:  849
# Nå har vi kommet til:  850
# Nå har vi kommet til:  851
# Nå har vi kommet til:  852
# Nå har vi kommet til:  853
# Nå har vi kommet til:  854
# Nå har vi kommet til:  855
# Nå har vi kommet til:  856
# Nå har vi kommet til:  857
# Nå har vi kommet til:  858
# Nå har vi kommet til:  859
# Nå har vi kommet til:  860
# Nå har vi kommet til:  861
# Nå har vi kommet til:  862
# Nå har vi kommet til:  863
# Nå har vi kommet til:  864
# Nå har vi kommet til:  865
# Nå har vi kommet til:  866
# Nå har vi kommet til:  867
# Nå har vi kommet til:  868
# Nå har vi kommet til:  869
# Nå har vi kommet til:  870
# Nå har vi kommet til:  871
# Nå har vi kommet til:  872
# Nå har vi kommet til:  873
# Nå har vi kommet til:  874
# Nå har vi kommet til:  875
# Nå har vi kommet til:  876
# Nå har vi kommet til:  877
# Nå har vi kommet til:  878
# Nå har vi kommet til:  879
# Nå har vi kommet til:  880
# Nå har vi kommet til:  881
# Nå har vi kommet til:  882
# Nå har vi kommet til:  883
# Nå har vi kommet til:  884
# Nå har vi kommet til:  885
# Nå har vi kommet til:  886
# Nå har vi kommet til:  887
# Nå har vi kommet til:  888
# Nå har vi kommet til:  889
# Nå har vi kommet til:  890
# Nå har vi kommet til:  891
# Nå har vi kommet til:  892
# Nå har vi kommet til:  893
# Nå har vi kommet til:  894
# Nå har vi kommet til:  895
# Nå har vi kommet til:  896
# Nå har vi kommet til:  897
# Nå har vi kommet til:  898
# Nå har vi kommet til:  899
# Nå har vi kommet til:  900
# Nå har vi kommet til:  901
# Nå har vi kommet til:  902
# Nå har vi kommet til:  903
# Nå har vi kommet til:  904
# Nå har vi kommet til:  905
# Nå har vi kommet til:  906
# Nå har vi kommet til:  907
# Nå har vi kommet til:  908
# Nå har vi kommet til:  909
# Nå har vi kommet til:  910
# Nå har vi kommet til:  911
# Nå har vi kommet til:  912
# Nå har vi kommet til:  913
# Nå har vi kommet til:  914
# Nå har vi kommet til:  915
# Nå har vi kommet til:  916
# Nå har vi kommet til:  917
# Nå har vi kommet til:  918
# Nå har vi kommet til:  919
# Nå har vi kommet til:  920
# Nå har vi kommet til:  921
# Nå har vi kommet til:  922
# Nå har vi kommet til:  923
# Nå har vi kommet til:  924
# Nå har vi kommet til:  925
# Nå har vi kommet til:  926
# Nå har vi kommet til:  927
# Nå har vi kommet til:  928
# Nå har vi kommet til:  929
# Nå har vi kommet til:  930
# Nå har vi kommet til:  931
# Nå har vi kommet til:  932
# Nå har vi kommet til:  933
# Nå har vi kommet til:  934
# Nå har vi kommet til:  935
# Nå har vi kommet til:  936
# Nå har vi kommet til:  937
# Nå har vi kommet til:  938
# Nå har vi kommet til:  939
# Nå har vi kommet til:  940
# Nå har vi kommet til:  941
# Nå har vi kommet til:  942
# Nå har vi kommet til:  943
# Nå har vi kommet til:  944
# Nå har vi kommet til:  945
# Nå har vi kommet til:  946
# Nå har vi kommet til:  947
# Nå har vi kommet til:  948
# Nå har vi kommet til:  949
# Nå har vi kommet til:  950
# Nå har vi kommet til:  951
# Nå har vi kommet til:  952
# Nå har vi kommet til:  953
# Nå har vi kommet til:  954
# Nå har vi kommet til:  955
# Nå har vi kommet til:  956
# Nå har vi kommet til:  957
# Nå har vi kommet til:  958
# Nå har vi kommet til:  959
# Nå har vi kommet til:  960
# Nå har vi kommet til:  961
# Nå har vi kommet til:  962
# Nå har vi kommet til:  963
# Nå har vi kommet til:  964
# Nå har vi kommet til:  965
# Nå har vi kommet til:  966
# Nå har vi kommet til:  967
# Nå har vi kommet til:  968
# Nå har vi kommet til:  969
# Nå har vi kommet til:  970
# Nå har vi kommet til:  971
# Nå har vi kommet til:  972
# Nå har vi kommet til:  973
# Nå har vi kommet til:  974
# Nå har vi kommet til:  975
# Nå har vi kommet til:  976
# Nå har vi kommet til:  977
# Nå har vi kommet til:  978
# Nå har vi kommet til:  979
# Nå har vi kommet til:  980
# Nå har vi kommet til:  981
# Nå har vi kommet til:  982
# Nå har vi kommet til:  983
# Nå har vi kommet til:  984
# Nå har vi kommet til:  985
# Nå har vi kommet til:  986
# Nå har vi kommet til:  987
# Nå har vi kommet til:  988
# Nå har vi kommet til:  989
# Nå har vi kommet til:  990
# Nå har vi kommet til:  991
# Nå har vi kommet til:  992
# Nå har vi kommet til:  993
# Nå har vi kommet til:  994
# Nå har vi kommet til:  995
# Nå har vi kommet til:  996
# Nå har vi kommet til:  997
# Nå har vi kommet til:  998
# Nå har vi kommet til:  999
# Nå har vi kommet til:  1000
# Nå har vi kommet til:  1001
# Nå har vi kommet til:  1002
# Nå har vi kommet til:  1003
# Nå har vi kommet til:  1004
# Nå har vi kommet til:  1005
# Nå har vi kommet til:  1006
# Nå har vi kommet til:  1007
# Nå har vi kommet til:  1008
# Nå har vi kommet til:  1009
# Nå har vi kommet til:  1010
# Nå har vi kommet til:  1011
# Nå har vi kommet til:  1012
# Nå har vi kommet til:  1013
# Nå har vi kommet til:  1014
# Nå har vi kommet til:  1015
# Nå har vi kommet til:  1016
# Nå har vi kommet til:  1017
# Nå har vi kommet til:  1018
# Nå har vi kommet til:  1019
# Nå har vi kommet til:  1020
# Nå har vi kommet til:  1021
# Nå har vi kommet til:  1022
# Nå har vi kommet til:  1023
# Nå har vi kommet til:  1024
# Nå har vi kommet til:  1025
# Nå har vi kommet til:  1026
# Nå har vi kommet til:  1027
# Nå har vi kommet til:  1028
# Nå har vi kommet til:  1029
# Nå har vi kommet til:  1030
# Nå har vi kommet til:  1031
# Nå har vi kommet til:  1032
# Nå har vi kommet til:  1033
# Nå har vi kommet til:  1034
# Nå har vi kommet til:  1035
# Nå har vi kommet til:  1036
# Nå har vi kommet til:  1037
# Nå har vi kommet til:  1038
# Nå har vi kommet til:  1039
# Nå har vi kommet til:  1040
# Nå har vi kommet til:  1041
# Nå har vi kommet til:  1042
# Nå har vi kommet til:  1043
# Nå har vi kommet til:  1044
# Nå har vi kommet til:  1045
# Nå har vi kommet til:  1046
# Nå har vi kommet til:  1047
# Nå har vi kommet til:  1048
# Nå har vi kommet til:  1049
# Nå har vi kommet til:  1050
# Nå har vi kommet til:  1051
# Nå har vi kommet til:  1052
# Nå har vi kommet til:  1053
# Nå har vi kommet til:  1054
# Nå har vi kommet til:  1055
# Nå har vi kommet til:  1056
# Nå har vi kommet til:  1057
# Nå har vi kommet til:  1058
# Nå har vi kommet til:  1059
# Nå har vi kommet til:  1060
# Nå har vi kommet til:  1061
# Nå har vi kommet til:  1062
# Nå har vi kommet til:  1063
# Nå har vi kommet til:  1064
# Nå har vi kommet til:  1065
# Nå har vi kommet til:  1066
# Nå har vi kommet til:  1067
# Nå har vi kommet til:  1068
# Nå har vi kommet til:  1069
# Nå har vi kommet til:  1070
# Nå har vi kommet til:  1071
# Nå har vi kommet til:  1072
# Nå har vi kommet til:  1073
# Nå har vi kommet til:  1074
# Nå har vi kommet til:  1075
# Nå har vi kommet til:  1076
# Nå har vi kommet til:  1077
# Nå har vi kommet til:  1078
# Nå har vi kommet til:  1079
# Nå har vi kommet til:  1080
# Nå har vi kommet til:  1081
# Nå har vi kommet til:  1082
# Nå har vi kommet til:  1083
# Nå har vi kommet til:  1084
# Nå har vi kommet til:  1085
# Nå har vi kommet til:  1086
# Nå har vi kommet til:  1087
# Nå har vi kommet til:  1088
# Nå har vi kommet til:  1089
# Nå har vi kommet til:  1090
# Nå har vi kommet til:  1091
# Nå har vi kommet til:  1092
# Nå har vi kommet til:  1093
# Nå har vi kommet til:  1094
# Nå har vi kommet til:  1095
# Nå har vi kommet til:  1096
# Nå har vi kommet til:  1097
# Nå har vi kommet til:  1098
# Nå har vi kommet til:  1099
# Nå har vi kommet til:  1100
# Nå har vi kommet til:  1101
# Nå har vi kommet til:  1102
# Nå har vi kommet til:  1103
# Nå har vi kommet til:  1104
# Nå har vi kommet til:  1105
# Nå har vi kommet til:  1106
# Nå har vi kommet til:  1107
# Nå har vi kommet til:  1108
# Nå har vi kommet til:  1109
# Nå har vi kommet til:  1110
# Nå har vi kommet til:  1111
# Nå har vi kommet til:  1112
# Nå har vi kommet til:  1113
# Nå har vi kommet til:  1114
# Nå har vi kommet til:  1115
# Nå har vi kommet til:  1116
# Nå har vi kommet til:  1117
# Nå har vi kommet til:  1118
# Nå har vi kommet til:  1119
# Nå har vi kommet til:  1120
# Nå har vi kommet til:  1121
# Nå har vi kommet til:  1122
# Nå har vi kommet til:  1123
# Nå har vi kommet til:  1124
# Nå har vi kommet til:  1125
# Nå har vi kommet til:  1126
# Nå har vi kommet til:  1127
# Nå har vi kommet til:  1128
# Nå har vi kommet til:  1129
# Nå har vi kommet til:  1130
# Nå har vi kommet til:  1131
# Nå har vi kommet til:  1132
# Nå har vi kommet til:  1133
# Nå har vi kommet til:  1134
# Nå har vi kommet til:  1135
# Nå har vi kommet til:  1136
# Nå har vi kommet til:  1137
# Nå har vi kommet til:  1138
# Nå har vi kommet til:  1139
# Nå har vi kommet til:  1140
# Nå har vi kommet til:  1141
# Nå har vi kommet til:  1142
# Nå har vi kommet til:  1143
# Nå har vi kommet til:  1144
# Nå har vi kommet til:  1145
# Nå har vi kommet til:  1146
# Nå har vi kommet til:  1147
# Nå har vi kommet til:  1148
# Nå har vi kommet til:  1149
# Nå har vi kommet til:  1150
# Nå har vi kommet til:  1151
# Nå har vi kommet til:  1152
# Nå har vi kommet til:  1153
# Nå har vi kommet til:  1154
# Nå har vi kommet til:  1155
# Nå har vi kommet til:  1156
# Nå har vi kommet til:  1157
# Nå har vi kommet til:  1158
# Nå har vi kommet til:  1159
# Nå har vi kommet til:  1160
# Nå har vi kommet til:  1161
# Nå har vi kommet til:  1162
# Nå har vi kommet til:  1163
# Nå har vi kommet til:  1164
# Nå har vi kommet til:  1165
# Nå har vi kommet til:  1166
# Nå har vi kommet til:  1167
# Nå har vi kommet til:  1168
# Nå har vi kommet til:  1169
# Nå har vi kommet til:  1170
# Nå har vi kommet til:  1171
# Nå har vi kommet til:  1172
# Nå har vi kommet til:  1173
# Nå har vi kommet til:  1174
# Nå har vi kommet til:  1175
# Nå har vi kommet til:  1176
# Nå har vi kommet til:  1177
# Nå har vi kommet til:  1178
# Nå har vi kommet til:  1179
# Nå har vi kommet til:  1180
# Nå har vi kommet til:  1181
# Nå har vi kommet til:  1182
# Nå har vi kommet til:  1183
# Nå har vi kommet til:  1184
# Nå har vi kommet til:  1185
# Nå har vi kommet til:  1186
# Nå har vi kommet til:  1187
# Nå har vi kommet til:  1188
# Nå har vi kommet til:  1189
# Nå har vi kommet til:  1190
# Nå har vi kommet til:  1191
# Nå har vi kommet til:  1192
# Nå har vi kommet til:  1193
# Nå har vi kommet til:  1194
# Nå har vi kommet til:  1195
# Nå har vi kommet til:  1196
# Nå har vi kommet til:  1197
# Nå har vi kommet til:  1198
# Nå har vi kommet til:  1199
# Nå har vi kommet til:  1200
# Nå har vi kommet til:  1201
# Nå har vi kommet til:  1202
# Nå har vi kommet til:  1203
# Nå har vi kommet til:  1204
# Nå har vi kommet til:  1205
# Nå har vi kommet til:  1206
# Nå har vi kommet til:  1207
# Nå har vi kommet til:  1208
# Nå har vi kommet til:  1209
# Nå har vi kommet til:  1210
# Nå har vi kommet til:  1211
# Nå har vi kommet til:  1212
# Nå har vi kommet til:  1213
# Nå har vi kommet til:  1214
# Nå har vi kommet til:  1215
# Nå har vi kommet til:  1216
# Nå har vi kommet til:  1217
# Nå har vi kommet til:  1218
# Nå har vi kommet til:  1219
# Nå har vi kommet til:  1220
# Nå har vi kommet til:  1221
# Nå har vi kommet til:  1222
# Nå har vi kommet til:  1223
# Nå har vi kommet til:  1224
# Nå har vi kommet til:  1225
# Nå har vi kommet til:  1226
# Nå har vi kommet til:  1227
# Nå har vi kommet til:  1228
# Nå har vi kommet til:  1229
# Nå har vi kommet til:  1230
# Nå har vi kommet til:  1231
# Nå har vi kommet til:  1232
# Nå har vi kommet til:  1233
# Nå har vi kommet til:  1234
# Nå har vi kommet til:  1235
# Nå har vi kommet til:  1236
# Nå har vi kommet til:  1237
# Nå har vi kommet til:  1238
# Nå har vi kommet til:  1239
# Nå har vi kommet til:  1240
# Nå har vi kommet til:  1241
# Nå har vi kommet til:  1242
# Nå har vi kommet til:  1243
# Nå har vi kommet til:  1244
# Nå har vi kommet til:  1245
# Nå har vi kommet til:  1246
# Nå har vi kommet til:  1247
# Nå har vi kommet til:  1248
# Nå har vi kommet til:  1249
# Nå har vi kommet til:  1250
# Nå har vi kommet til:  1251
# Nå har vi kommet til:  1252
# Nå har vi kommet til:  1253
# Nå har vi kommet til:  1254
# Nå har vi kommet til:  1255
# Nå har vi kommet til:  1256
# Nå har vi kommet til:  1257
# Nå har vi kommet til:  1258
# Nå har vi kommet til:  1259
# Nå har vi kommet til:  1260
# Nå har vi kommet til:  1261
# Nå har vi kommet til:  1262
# Nå har vi kommet til:  1263
# Nå har vi kommet til:  1264
# Nå har vi kommet til:  1265
# Nå har vi kommet til:  1266
# Nå har vi kommet til:  1267
# Nå har vi kommet til:  1268
# Nå har vi kommet til:  1269
# Nå har vi kommet til:  1270
# Nå har vi kommet til:  1271
# Nå har vi kommet til:  1272
# Nå har vi kommet til:  1273
# Nå har vi kommet til:  1274
# Nå har vi kommet til:  1275
# Nå har vi kommet til:  1276
# Nå har vi kommet til:  1277
# Nå har vi kommet til:  1278
# Nå har vi kommet til:  1279
# Nå har vi kommet til:  1280
# Nå har vi kommet til:  1281
# Nå har vi kommet til:  1282
# Nå har vi kommet til:  1283
# Nå har vi kommet til:  1284
# Nå har vi kommet til:  1285
# Nå har vi kommet til:  1286
# Nå har vi kommet til:  1287
# Nå har vi kommet til:  1288
# Nå har vi kommet til:  1289
# Nå har vi kommet til:  1290
# Nå har vi kommet til:  1291
# Nå har vi kommet til:  1292
# Nå har vi kommet til:  1293
# Nå har vi kommet til:  1294
# Nå har vi kommet til:  1295
# Nå har vi kommet til:  1296
# Nå har vi kommet til:  1297
# Nå har vi kommet til:  1298
# Nå har vi kommet til:  1299
# Nå har vi kommet til:  1300
# Nå har vi kommet til:  1301
# Nå har vi kommet til:  1302
# Nå har vi kommet til:  1303
# Nå har vi kommet til:  1304
# Nå har vi kommet til:  1305
# Nå har vi kommet til:  1306
# Nå har vi kommet til:  1307
# Nå har vi kommet til:  1308
# Nå har vi kommet til:  1309
# Nå har vi kommet til:  1310
# Nå har vi kommet til:  1311
# Nå har vi kommet til:  1312
# Nå har vi kommet til:  1313
# Nå har vi kommet til:  1314
# Nå har vi kommet til:  1315
# Nå har vi kommet til:  1316
# Nå har vi kommet til:  1317
# Nå har vi kommet til:  1318
# Nå har vi kommet til:  1319
# Nå har vi kommet til:  1320
# Nå har vi kommet til:  1321
# Nå har vi kommet til:  1322
# Nå har vi kommet til:  1323
# Nå har vi kommet til:  1324
# Nå har vi kommet til:  1325
# Nå har vi kommet til:  1326
# Nå har vi kommet til:  1327
# Nå har vi kommet til:  1328
# Nå har vi kommet til:  1329
# Nå har vi kommet til:  1330
# Nå har vi kommet til:  1331
# Nå har vi kommet til:  1332
# Nå har vi kommet til:  1333
# Nå har vi kommet til:  1334
# Nå har vi kommet til:  1335
# Nå har vi kommet til:  1336
# Nå har vi kommet til:  1337
# Nå har vi kommet til:  1338
# Nå har vi kommet til:  1339
# Nå har vi kommet til:  1340
# Nå har vi kommet til:  1341
# Nå har vi kommet til:  1342
# Nå har vi kommet til:  1343
# Nå har vi kommet til:  1344
# Nå har vi kommet til:  1345
# Nå har vi kommet til:  1346
# Nå har vi kommet til:  1347
# Nå har vi kommet til:  1348
# Nå har vi kommet til:  1349
# Nå har vi kommet til:  1350
# Nå har vi kommet til:  1351
# Nå har vi kommet til:  1352
# Nå har vi kommet til:  1353
# Nå har vi kommet til:  1354
# Nå har vi kommet til:  1355
# Nå har vi kommet til:  1356
# Nå har vi kommet til:  1357
# Nå har vi kommet til:  1358
# Nå har vi kommet til:  1359
# Nå har vi kommet til:  1360
# Nå har vi kommet til:  1361
# Nå har vi kommet til:  1362
# Nå har vi kommet til:  1363
# Nå har vi kommet til:  1364
# Nå har vi kommet til:  1365
# Nå har vi kommet til:  1366
# Nå har vi kommet til:  1367
# Nå har vi kommet til:  1368
# Nå har vi kommet til:  1369
# Nå har vi kommet til:  1370
# Nå har vi kommet til:  1371
# Nå har vi kommet til:  1372
# Nå har vi kommet til:  1373
# Nå har vi kommet til:  1374
# Nå har vi kommet til:  1375
# Nå har vi kommet til:  1376
# Nå har vi kommet til:  1377
# Nå har vi kommet til:  1378
# Nå har vi kommet til:  1379
# Nå har vi kommet til:  1380
# Nå har vi kommet til:  1381
# Nå har vi kommet til:  1382
# Nå har vi kommet til:  1383
# Nå har vi kommet til:  1384
# Nå har vi kommet til:  1385
# Nå har vi kommet til:  1386
# Nå har vi kommet til:  1387
# Nå har vi kommet til:  1388
# Nå har vi kommet til:  1389
# Nå har vi kommet til:  1390
# Nå har vi kommet til:  1391
# Nå har vi kommet til:  1392
# Nå har vi kommet til:  1393
# Nå har vi kommet til:  1394
# Nå har vi kommet til:  1395
# Nå har vi kommet til:  1396
# Nå har vi kommet til:  1397
# Nå har vi kommet til:  1398
# Nå har vi kommet til:  1399
# Nå har vi kommet til:  1400
# Nå har vi kommet til:  1401
# Nå har vi kommet til:  1402
# Nå har vi kommet til:  1403
# Nå har vi kommet til:  1404
# Nå har vi kommet til:  1405
# Nå har vi kommet til:  1406
# Nå har vi kommet til:  1407
# Nå har vi kommet til:  1408
# Nå har vi kommet til:  1409
# Nå har vi kommet til:  1410
# Nå har vi kommet til:  1411
# Nå har vi kommet til:  1412
# Nå har vi kommet til:  1413
# Nå har vi kommet til:  1414
# Nå har vi kommet til:  1415
# Nå har vi kommet til:  1416
# Nå har vi kommet til:  1417
# Nå har vi kommet til:  1418
# Nå har vi kommet til:  1419
# Nå har vi kommet til:  1420
# Nå har vi kommet til:  1421
# Nå har vi kommet til:  1422
# Nå har vi kommet til:  1423
# Nå har vi kommet til:  1424
# Nå har vi kommet til:  1425
# Nå har vi kommet til:  1426
# Nå har vi kommet til:  1427
# Nå har vi kommet til:  1428
# Nå har vi kommet til:  1429
# Nå har vi kommet til:  1430
# Nå har vi kommet til:  1431
# Nå har vi kommet til:  1432
# Nå har vi kommet til:  1433
# Nå har vi kommet til:  1434
# Nå har vi kommet til:  1435
# Nå har vi kommet til:  1436
# Nå har vi kommet til:  1437
# Nå har vi kommet til:  1438
# Nå har vi kommet til:  1439
# Nå har vi kommet til:  1440
# Nå har vi kommet til:  1441
# Nå har vi kommet til:  1442
# Nå har vi kommet til:  1443
# Nå har vi kommet til:  1444
# Nå har vi kommet til:  1445
# Nå har vi kommet til:  1446
# Nå har vi kommet til:  1447
# Nå har vi kommet til:  1448
# Nå har vi kommet til:  1449
# Nå har vi kommet til:  1450
# Nå har vi kommet til:  1451
# Nå har vi kommet til:  1452
# Nå har vi kommet til:  1453
# Nå har vi kommet til:  1454
# Nå har vi kommet til:  1455
# Nå har vi kommet til:  1456
# Nå har vi kommet til:  1457
# Nå har vi kommet til:  1458
# Nå har vi kommet til:  1459
# Nå har vi kommet til:  1460
# Nå har vi kommet til:  1461
# Nå har vi kommet til:  1462
# Nå har vi kommet til:  1463
# Nå har vi kommet til:  1464
# Nå har vi kommet til:  1465
# Nå har vi kommet til:  1466
# Nå har vi kommet til:  1467
# Nå har vi kommet til:  1468
# Nå har vi kommet til:  1469
# Nå har vi kommet til:  1470
# Nå har vi kommet til:  1471
# Nå har vi kommet til:  1472
# Nå har vi kommet til:  1473
# Nå har vi kommet til:  1474
# Nå har vi kommet til:  1475
# Nå har vi kommet til:  1476
# Nå har vi kommet til:  1477
# Nå har vi kommet til:  1478
# Nå har vi kommet til:  1479
# Nå har vi kommet til:  1480
# Nå har vi kommet til:  1481
# Nå har vi kommet til:  1482
# Nå har vi kommet til:  1483
# Nå har vi kommet til:  1484
# Nå har vi kommet til:  1485
# Nå har vi kommet til:  1486
# Nå har vi kommet til:  1487
# Nå har vi kommet til:  1488
# Nå har vi kommet til:  1489
# Nå har vi kommet til:  1490
# Nå har vi kommet til:  1491
# Nå har vi kommet til:  1492
# Nå har vi kommet til:  1493
# Nå har vi kommet til:  1494
# Nå har vi kommet til:  1495
# Nå har vi kommet til:  1496
# Nå har vi kommet til:  1497
# Nå har vi kommet til:  1498
# Nå har vi kommet til:  1499
# Nå har vi kommet til:  1500
# Nå har vi kommet til:  1501
# Nå har vi kommet til:  1502
# Nå har vi kommet til:  1503
# Nå har vi kommet til:  1504
# Nå har vi kommet til:  1505
# Nå har vi kommet til:  1506
# Nå har vi kommet til:  1507
# Nå har vi kommet til:  1508
# Nå har vi kommet til:  1509
# Nå har vi kommet til:  1510
# Nå har vi kommet til:  1511
# Nå har vi kommet til:  1512
# Nå har vi kommet til:  1513
# Nå har vi kommet til:  1514
# Nå har vi kommet til:  1515
# Nå har vi kommet til:  1516
# Nå har vi kommet til:  1517
# Nå har vi kommet til:  1518
# Nå har vi kommet til:  1519
# Nå har vi kommet til:  1520
# Nå har vi kommet til:  1521
# Nå har vi kommet til:  1522
# Nå har vi kommet til:  1523
# Nå har vi kommet til:  1524
# Nå har vi kommet til:  1525
# Nå har vi kommet til:  1526
# Nå har vi kommet til:  1527
# Nå har vi kommet til:  1528
# Nå har vi kommet til:  1529
# Nå har vi kommet til:  1530
# Nå har vi kommet til:  1531
# Nå har vi kommet til:  1532
# Nå har vi kommet til:  1533
# Nå har vi kommet til:  1534
# Nå har vi kommet til:  1535
# Nå har vi kommet til:  1536
# Nå har vi kommet til:  1537
# Nå har vi kommet til:  1538
# Nå har vi kommet til:  1539
# Nå har vi kommet til:  1540
# Nå har vi kommet til:  1541
# Nå har vi kommet til:  1542
# Nå har vi kommet til:  1543
# Nå har vi kommet til:  1544
# Nå har vi kommet til:  1545
# Nå har vi kommet til:  1546
# Nå har vi kommet til:  1547
# Nå har vi kommet til:  1548
# Nå har vi kommet til:  1549
# Nå har vi kommet til:  1550
# Nå har vi kommet til:  1551
# Nå har vi kommet til:  1552
# Nå har vi kommet til:  1553
# Nå har vi kommet til:  1554
# Nå har vi kommet til:  1555
# Nå har vi kommet til:  1556
# Nå har vi kommet til:  1557
# Nå har vi kommet til:  1558
# Nå har vi kommet til:  1559
# Nå har vi kommet til:  1560
# Nå har vi kommet til:  1561
# Nå har vi kommet til:  1562
# Nå har vi kommet til:  1563
# Nå har vi kommet til:  1564
# Nå har vi kommet til:  1565
# Nå har vi kommet til:  1566
# Nå har vi kommet til:  1567
# Nå har vi kommet til:  1568
# Nå har vi kommet til:  1569
# Nå har vi kommet til:  1570
# Nå har vi kommet til:  1571
# Nå har vi kommet til:  1572
# Nå har vi kommet til:  1573
# Nå har vi kommet til:  1574
# Nå har vi kommet til:  1575
# Nå har vi kommet til:  1576
# Nå har vi kommet til:  1577
# Nå har vi kommet til:  1578
# Nå har vi kommet til:  1579
# Nå har vi kommet til:  1580
# Nå har vi kommet til:  1581
# Nå har vi kommet til:  1582
# Nå har vi kommet til:  1583
# Nå har vi kommet til:  1584
# Nå har vi kommet til:  1585
# Nå har vi kommet til:  1586
# Nå har vi kommet til:  1587
# Nå har vi kommet til:  1588
# Nå har vi kommet til:  1589
# Nå har vi kommet til:  1590
# Nå har vi kommet til:  1591
# Nå har vi kommet til:  1592
# Nå har vi kommet til:  1593
# Nå har vi kommet til:  1594
# Nå har vi kommet til:  1595
# Nå har vi kommet til:  1596
# Nå har vi kommet til:  1597
# Nå har vi kommet til:  1598
# Nå har vi kommet til:  1599
# Nå har vi kommet til:  1600
# Nå har vi kommet til:  1601
# Nå har vi kommet til:  1602
# Nå har vi kommet til:  1603
# Nå har vi kommet til:  1604
# Nå har vi kommet til:  1605
# Nå har vi kommet til:  1606
# Nå har vi kommet til:  1607
# Nå har vi kommet til:  1608
# Nå har vi kommet til:  1609
# Nå har vi kommet til:  1610
# Nå har vi kommet til:  1611
# Nå har vi kommet til:  1612
# Nå har vi kommet til:  1613
# Nå har vi kommet til:  1614
# Nå har vi kommet til:  1615
# Nå har vi kommet til:  1616
# Nå har vi kommet til:  1617
# Nå har vi kommet til:  1618
# Nå har vi kommet til:  1619
# Nå har vi kommet til:  1620
# Nå har vi kommet til:  1621
# Nå har vi kommet til:  1622
# Nå har vi kommet til:  1623
# Nå har vi kommet til:  1624
# Nå har vi kommet til:  1625
# Nå har vi kommet til:  1626
# Nå har vi kommet til:  1627
# Nå har vi kommet til:  1628
# Nå har vi kommet til:  1629
# Nå har vi kommet til:  1630
# Nå har vi kommet til:  1631
# Nå har vi kommet til:  1632
# Nå har vi kommet til:  1633
# Nå har vi kommet til:  1634
# Nå har vi kommet til:  1635
# Nå har vi kommet til:  1636
# Nå har vi kommet til:  1637
# Nå har vi kommet til:  1638
# Nå har vi kommet til:  1639
# Nå har vi kommet til:  1640
# Nå har vi kommet til:  1641
# Nå har vi kommet til:  1642
# Nå har vi kommet til:  1643
# Nå har vi kommet til:  1644
# Nå har vi kommet til:  1645
# Nå har vi kommet til:  1646
# Nå har vi kommet til:  1647
# Nå har vi kommet til:  1648
# Nå har vi kommet til:  1649
# Nå har vi kommet til:  1650
# Nå har vi kommet til:  1651
# Nå har vi kommet til:  1652
# Nå har vi kommet til:  1653
# Nå har vi kommet til:  1654
# Nå har vi kommet til:  1655
# Nå har vi kommet til:  1656
# Nå har vi kommet til:  1657
# Nå har vi kommet til:  1658
# Nå har vi kommet til:  1659
# Nå har vi kommet til:  1660
# Nå har vi kommet til:  1661
# Nå har vi kommet til:  1662
# Nå har vi kommet til:  1663
# Nå har vi kommet til:  1664
# Nå har vi kommet til:  1665
# Nå har vi kommet til:  1666
# Nå har vi kommet til:  1667
# Nå har vi kommet til:  1668
# Nå har vi kommet til:  1669
# Nå har vi kommet til:  1670
# Nå har vi kommet til:  1671
# Nå har vi kommet til:  1672
# Nå har vi kommet til:  1673
# Nå har vi kommet til:  1674
# Nå har vi kommet til:  1675
# Nå har vi kommet til:  1676
# Nå har vi kommet til:  1677
# Nå har vi kommet til:  1678
# Nå har vi kommet til:  1679
# Nå har vi kommet til:  1680
# Nå har vi kommet til:  1681
# Nå har vi kommet til:  1682
# Nå har vi kommet til:  1683
# Nå har vi kommet til:  1684
# Nå har vi kommet til:  1685
# Nå har vi kommet til:  1686
# Nå har vi kommet til:  1687
# Nå har vi kommet til:  1688
# Nå har vi kommet til:  1689
# Nå har vi kommet til:  1690
# Nå har vi kommet til:  1691
# Nå har vi kommet til:  1692
# Nå har vi kommet til:  1693
# Nå har vi kommet til:  1694
# Nå har vi kommet til:  1695
# Nå har vi kommet til:  1696
# Nå har vi kommet til:  1697
# Nå har vi kommet til:  1698
# Nå har vi kommet til:  1699
# Nå har vi kommet til:  1700
# Nå har vi kommet til:  1701
# Nå har vi kommet til:  1702
# Nå har vi kommet til:  1703
# Nå har vi kommet til:  1704
# Nå har vi kommet til:  1705
# Nå har vi kommet til:  1706
# Nå har vi kommet til:  1707
# Nå har vi kommet til:  1708
# Nå har vi kommet til:  1709
# Nå har vi kommet til:  1710
# Nå har vi kommet til:  1711
# Nå har vi kommet til:  1712
# Nå har vi kommet til:  1713
# Nå har vi kommet til:  1714
# Nå har vi kommet til:  1715
# Nå har vi kommet til:  1716
# Nå har vi kommet til:  1717
# Nå har vi kommet til:  1718
# Nå har vi kommet til:  1719
# Nå har vi kommet til:  1720
# Nå har vi kommet til:  1721
# Nå har vi kommet til:  1722
# Nå har vi kommet til:  1723
# Nå har vi kommet til:  1724
# Nå har vi kommet til:  1725
# Nå har vi kommet til:  1726
# Nå har vi kommet til:  1727
# Nå har vi kommet til:  1728
# Nå har vi kommet til:  1729
# Nå har vi kommet til:  1730
# Nå har vi kommet til:  1731
# Nå har vi kommet til:  1732
# Nå har vi kommet til:  1733
# Nå har vi kommet til:  1734
# Nå har vi kommet til:  1735
# Nå har vi kommet til:  1736
# Nå har vi kommet til:  1737
# Nå har vi kommet til:  1738
# Nå har vi kommet til:  1739
# Nå har vi kommet til:  1740
# Nå har vi kommet til:  1741
# Nå har vi kommet til:  1742
# Nå har vi kommet til:  1743
# Nå har vi kommet til:  1744
# Nå har vi kommet til:  1745
# Nå har vi kommet til:  1746
# Nå har vi kommet til:  1747
# Nå har vi kommet til:  1748
# Nå har vi kommet til:  1749
# Nå har vi kommet til:  1750
# Nå har vi kommet til:  1751
# Nå har vi kommet til:  1752
# ...
# Nå har vi kommet til:  2413
# Nå har vi kommet til:  2414
# Nå har vi kommet til:  2415
# Nå har vi kommet til:  2416
# Nå har vi kommet til:  2417
# Nå har vi kommet til:  2418
# Nå har vi kommet til:  2419
# Nå har vi kommet til:  2420
# Nå har vi kommet til:  2421
# Nå har vi kommet til:  2422
# Nå har vi kommet til:  2423
# Nå har vi kommet til:  2424
# Nå har vi kommet til:  2425
# Nå har vi kommet til:  2426
# Nå har vi kommet til:  2427
# Nå har vi kommet til:  2428
# Nå har vi kommet til:  2429
# Nå har vi kommet til:  2430
# Nå har vi kommet til:  2431
# Nå har vi kommet til:  2432
# Nå har vi kommet til:  2433
# Nå har vi kommet til:  2434
# Nå har vi kommet til:  2435
# Nå har vi kommet til:  2436
# Nå har vi kommet til:  2437
# Nå har vi kommet til:  2438
# Nå har vi kommet til:  2439
# Nå har vi kommet til:  2440
# Nå har vi kommet til:  2441
# Nå har vi kommet til:  2442
# Nå har vi kommet til:  2443
# Nå har vi kommet til:  2444
# Nå har vi kommet til:  2445
# Nå har vi kommet til:  2446
# Nå har vi kommet til:  2447
# Nå har vi kommet til:  2448
# Nå har vi kommet til:  2449
# Nå har vi kommet til:  2450
# Nå har vi kommet til:  2451
# Nå har vi kommet til:  2452
# Nå har vi kommet til:  2453
# Nå har vi kommet til:  2454
# Nå har vi kommet til:  2455
# Nå har vi kommet til:  2456
# Nå har vi kommet til:  2457
# Nå har vi kommet til:  2458
# Nå har vi kommet til:  2459
# Nå har vi kommet til:  2460
# Nå har vi kommet til:  2461
# Nå har vi kommet til:  2462
# Nå har vi kommet til:  2463
# Nå har vi kommet til:  2464
# Nå har vi kommet til:  2465
# Nå har vi kommet til:  2466
# Nå har vi kommet til:  2467
# Nå har vi kommet til:  2468
# Nå har vi kommet til:  2469
# Nå har vi kommet til:  2470
# Nå har vi kommet til:  2471
# Nå har vi kommet til:  2472
# Nå har vi kommet til:  2473
# Nå har vi kommet til:  2474
# Nå har vi kommet til:  2475
# Nå har vi kommet til:  2476
# Nå har vi kommet til:  2477
# Nå har vi kommet til:  2478
# Nå har vi kommet til:  2479
# Nå har vi kommet til:  2480
# Nå har vi kommet til:  2481
# Nå har vi kommet til:  2482
# Nå har vi kommet til:  2483
# Nå har vi kommet til:  2484
# Nå har vi kommet til:  2485
# Nå har vi kommet til:  2486
# Nå har vi kommet til:  2487
# Nå har vi kommet til:  2488
# Nå har vi kommet til:  2489
# Nå har vi kommet til:  2490
# Nå har vi kommet til:  2491
# Nå har vi kommet til:  2492
# Nå har vi kommet til:  2493
# Nå har vi kommet til:  2494
# Nå har vi kommet til:  2495
# Nå har vi kommet til:  2496
# Nå har vi kommet til:  2497
# Nå har vi kommet til:  2498
# Nå har vi kommet til:  2499
# Nå har vi kommet til:  2500
# Nå har vi kommet til:  2501
# Nå har vi kommet til:  2502
# Nå har vi kommet til:  2503
# Nå har vi kommet til:  2504
# Nå har vi kommet til:  2505
# Nå har vi kommet til:  2506
# Nå har vi kommet til:  2507
# Nå har vi kommet til:  2508
# Nå har vi kommet til:  2509
# Nå har vi kommet til:  2510
# Nå har vi kommet til:  2511
# Nå har vi kommet til:  2512
# Nå har vi kommet til:  2513
# Nå har vi kommet til:  2514
# Nå har vi kommet til:  2515
# Nå har vi kommet til:  2516
# Nå har vi kommet til:  2517
# Nå har vi kommet til:  2518
# Nå har vi kommet til:  2519
# Nå har vi kommet til:  2520
# Nå har vi kommet til:  2521
# Nå har vi kommet til:  2522
# Nå har vi kommet til:  2523
# Nå har vi kommet til:  2524
# Nå har vi kommet til:  2525
# Nå har vi kommet til:  2526
# Nå har vi kommet til:  2527
# Nå har vi kommet til:  2528
# Nå har vi kommet til:  2529
# Nå har vi kommet til:  2530
# Nå har vi kommet til:  2531
# Nå har vi kommet til:  2532
# Nå har vi kommet til:  2533
# Nå har vi kommet til:  2534
# Nå har vi kommet til:  2535
# Nå har vi kommet til:  2536
# Nå har vi kommet til:  2537
# Nå har vi kommet til:  2538
# Nå har vi kommet til:  2539
# Nå har vi kommet til:  2540
# Nå har vi kommet til:  2541
# Nå har vi kommet til:  2542
# Nå har vi kommet til:  2543
# Nå har vi kommet til:  2544
# Nå har vi kommet til:  2545
# Nå har vi kommet til:  2546
# Nå har vi kommet til:  2547
# Nå har vi kommet til:  2548
# Nå har vi kommet til:  2549
# Nå har vi kommet til:  2550
# Nå har vi kommet til:  2551
# Nå har vi kommet til:  2552
# Nå har vi kommet til:  2553
# Nå har vi kommet til:  2554
# Nå har vi kommet til:  2555
# Nå har vi kommet til:  2556
# Nå har vi kommet til:  2557
# Nå har vi kommet til:  2558
# Nå har vi kommet til:  2559
# Nå har vi kommet til:  2560
# Nå har vi kommet til:  2561
# Nå har vi kommet til:  2562
# Nå har vi kommet til:  2563
# Nå har vi kommet til:  2564
# Nå har vi kommet til:  2565
# Nå har vi kommet til:  2566
# Nå har vi kommet til:  2567
# Nå har vi kommet til:  2568
# Nå har vi kommet til:  2569
# Nå har vi kommet til:  2570
# Nå har vi kommet til:  2571
# Nå har vi kommet til:  2572
# Nå har vi kommet til:  2573
# Nå har vi kommet til:  2574
# Nå har vi kommet til:  2575
# Nå har vi kommet til:  2576
# Nå har vi kommet til:  2577
# Nå har vi kommet til:  2578
# Nå har vi kommet til:  2579
# Nå har vi kommet til:  2580
# Nå har vi kommet til:  2581
# Nå har vi kommet til:  2582
# Nå har vi kommet til:  2583
# Nå har vi kommet til:  2584
# Nå har vi kommet til:  2585
# Nå har vi kommet til:  2586
# Nå har vi kommet til:  2587
# Nå har vi kommet til:  2588
# Nå har vi kommet til:  2589
# Nå har vi kommet til:  2590
# Nå har vi kommet til:  2591
# Nå har vi kommet til:  2592
# Nå har vi kommet til:  2593
# Nå har vi kommet til:  2594
# Nå har vi kommet til:  2595
# Nå har vi kommet til:  2596
# Nå har vi kommet til:  2597
# Nå har vi kommet til:  2598
# Nå har vi kommet til:  2599
# Nå har vi kommet til:  2600
# Nå har vi kommet til:  2601
# Nå har vi kommet til:  2602
# Nå har vi kommet til:  2603
# Nå har vi kommet til:  2604
# Nå har vi kommet til:  2605
# Nå har vi kommet til:  2606
# Nå har vi kommet til:  2607
# Nå har vi kommet til:  2608
# Nå har vi kommet til:  2609
# Nå har vi kommet til:  2610
# Nå har vi kommet til:  2611
# Nå har vi kommet til:  2612
# Nå har vi kommet til:  2613
# Nå har vi kommet til:  2614
# Nå har vi kommet til:  2615
# Nå har vi kommet til:  2616
# Nå har vi kommet til:  2617
# Nå har vi kommet til:  2618
# Nå har vi kommet til:  2619
# Nå har vi kommet til:  2620
# Nå har vi kommet til:  2621
# Nå har vi kommet til:  2622
# Nå har vi kommet til:  2623
# Nå har vi kommet til:  2624
# Nå har vi kommet til:  2625
# Nå har vi kommet til:  2626
# Nå har vi kommet til:  2627
# Nå har vi kommet til:  2628
# Nå har vi kommet til:  2629
# Nå har vi kommet til:  2630
# Nå har vi kommet til:  2631
# Nå har vi kommet til:  2632
# Nå har vi kommet til:  2633
# Nå har vi kommet til:  2634
# Nå har vi kommet til:  2635
# Nå har vi kommet til:  2636
# Nå har vi kommet til:  2637
# Nå har vi kommet til:  2638
# Nå har vi kommet til:  2639
# Nå har vi kommet til:  2640
# Nå har vi kommet til:  2641
# Nå har vi kommet til:  2642
# Nå har vi kommet til:  2643
# Nå har vi kommet til:  2644
# Nå har vi kommet til:  2645
# Nå har vi kommet til:  2646
# Nå har vi kommet til:  2647
# Nå har vi kommet til:  2648
# Nå har vi kommet til:  2649
# Nå har vi kommet til:  2650
# Nå har vi kommet til:  2651
# Nå har vi kommet til:  2652
# Nå har vi kommet til:  2653
# Nå har vi kommet til:  2654
# Nå har vi kommet til:  2655
# Nå har vi kommet til:  2656
# Nå har vi kommet til:  2657
# Nå har vi kommet til:  2658
# Nå har vi kommet til:  2659
# Nå har vi kommet til:  2660
# Nå har vi kommet til:  2661
# Nå har vi kommet til:  2662
# Nå har vi kommet til:  2663
# Nå har vi kommet til:  2664
# Nå har vi kommet til:  2665
# Nå har vi kommet til:  2666
# Nå har vi kommet til:  2667
# Nå har vi kommet til:  2668
# Nå har vi kommet til:  2669
# Nå har vi kommet til:  2670
# Nå har vi kommet til:  2671
# Nå har vi kommet til:  2672
# Nå har vi kommet til:  2673
# Nå har vi kommet til:  2674
# Nå har vi kommet til:  2675
# Nå har vi kommet til:  2676
# Nå har vi kommet til:  2677
# Nå har vi kommet til:  2678
# Nå har vi kommet til:  2679
# Nå har vi kommet til:  2680
# Nå har vi kommet til:  2681
# Nå har vi kommet til:  2682
# Nå har vi kommet til:  2683
# Nå har vi kommet til:  2684
# Nå har vi kommet til:  2685
# Nå har vi kommet til:  2686
# Nå har vi kommet til:  2687
# Nå har vi kommet til:  2688
# Nå har vi kommet til:  2689
# Nå har vi kommet til:  2690
# Nå har vi kommet til:  2691
# Nå har vi kommet til:  2692
# Nå har vi kommet til:  2693
# Nå har vi kommet til:  2694
# Nå har vi kommet til:  2695
# Nå har vi kommet til:  2696
# Nå har vi kommet til:  2697
# Nå har vi kommet til:  2698
# Nå har vi kommet til:  2699
# Nå har vi kommet til:  2700
# Nå har vi kommet til:  2701
# Nå har vi kommet til:  2702
# Nå har vi kommet til:  2703
# Nå har vi kommet til:  2704
# Nå har vi kommet til:  2705
# Nå har vi kommet til:  2706
# Nå har vi kommet til:  2707
# Nå har vi kommet til:  2708
# Nå har vi kommet til:  2709
# Nå har vi kommet til:  2710
# Nå har vi kommet til:  2711
# Nå har vi kommet til:  2712
# Nå har vi kommet til:  2713
# Nå har vi kommet til:  2714
# Nå har vi kommet til:  2715
# Nå har vi kommet til:  2716
# Nå har vi kommet til:  2717
# Nå har vi kommet til:  2718
# Nå har vi kommet til:  2719
# Nå har vi kommet til:  2720
# Nå har vi kommet til:  2721
# Nå har vi kommet til:  2722
# Nå har vi kommet til:  2723
# Nå har vi kommet til:  2724
# Nå har vi kommet til:  2725
# Nå har vi kommet til:  2726
# Nå har vi kommet til:  2727
# Nå har vi kommet til:  2728
# Nå har vi kommet til:  2729
# Nå har vi kommet til:  2730
# Nå har vi kommet til:  2731
# Nå har vi kommet til:  2732
# Nå har vi kommet til:  2733
# Nå har vi kommet til:  2734
# Nå har vi kommet til:  2735
# Nå har vi kommet til:  2736
# Nå har vi kommet til:  2737
# Nå har vi kommet til:  2738
# Nå har vi kommet til:  2739
# Nå har vi kommet til:  2740
# Nå har vi kommet til:  2741
# Nå har vi kommet til:  2742
# Nå har vi kommet til:  2743
# Nå har vi kommet til:  2744
# Nå har vi kommet til:  2745
# Nå har vi kommet til:  2746
# Nå har vi kommet til:  2747
# Nå har vi kommet til:  2748
# Nå har vi kommet til:  2749
# Nå har vi kommet til:  2750
# Nå har vi kommet til:  2751
# Nå har vi kommet til:  2752
# Nå har vi kommet til:  2753
# Nå har vi kommet til:  2754
# Nå har vi kommet til:  2755
# Nå har vi kommet til:  2756
# Nå har vi kommet til:  2757
# Nå har vi kommet til:  2758
# Nå har vi kommet til:  2759
# Nå har vi kommet til:  2760
# Nå har vi kommet til:  2761
# Nå har vi kommet til:  2762
# Nå har vi kommet til:  2763
# Nå har vi kommet til:  2764
# Nå har vi kommet til:  2765
# Nå har vi kommet til:  2766
# Nå har vi kommet til:  2767
# Nå har vi kommet til:  2768
# Nå har vi kommet til:  2769
# Nå har vi kommet til:  2770
# Nå har vi kommet til:  2771
# Nå har vi kommet til:  2772
# Nå har vi kommet til:  2773
# Nå har vi kommet til:  2774
# Nå har vi kommet til:  2775
# Nå har vi kommet til:  2776
# Nå har vi kommet til:  2777
# Nå har vi kommet til:  2778
# Nå har vi kommet til:  2779
# Nå har vi kommet til:  2780
# Nå har vi kommet til:  2781
# Nå har vi kommet til:  2782
# Nå har vi kommet til:  2783
# Nå har vi kommet til:  2784
# Nå har vi kommet til:  2785
# Nå har vi kommet til:  2786
# Nå har vi kommet til:  2787
# Nå har vi kommet til:  2788
# Nå har vi kommet til:  2789
# Nå har vi kommet til:  2790
# Nå har vi kommet til:  2791
# Nå har vi kommet til:  2792
# Nå har vi kommet til:  2793
# Nå har vi kommet til:  2794
# Nå har vi kommet til:  2795
# Nå har vi kommet til:  2796
# Nå har vi kommet til:  2797
# Nå har vi kommet til:  2798
# Nå har vi kommet til:  2799
# Nå har vi kommet til:  2800
# Nå har vi kommet til:  2801
# Nå har vi kommet til:  2802
# Nå har vi kommet til:  2803
# Nå har vi kommet til:  2804
# Nå har vi kommet til:  2805
# Nå har vi kommet til:  2806
# Nå har vi kommet til:  2807
# Nå har vi kommet til:  2808
# Nå har vi kommet til:  2809
# Nå har vi kommet til:  2810
# Nå har vi kommet til:  2811
# Nå har vi kommet til:  2812
# Nå har vi kommet til:  2813
# Nå har vi kommet til:  2814
# Nå har vi kommet til:  2815
# Nå har vi kommet til:  2816
# Nå har vi kommet til:  2817
# Nå har vi kommet til:  2818
# Nå har vi kommet til:  2819
# Nå har vi kommet til:  2820
# Nå har vi kommet til:  2821
# Nå har vi kommet til:  2822
# Nå har vi kommet til:  2823
# Nå har vi kommet til:  2824
# Nå har vi kommet til:  2825
# Nå har vi kommet til:  2826
# Nå har vi kommet til:  2827
# Nå har vi kommet til:  2828
# Nå har vi kommet til:  2829
# Nå har vi kommet til:  2830
# Nå har vi kommet til:  2831
# Nå har vi kommet til:  2832
# Nå har vi kommet til:  2833
# Nå har vi kommet til:  2834
# Nå har vi kommet til:  2835
# Nå har vi kommet til:  2836
# Nå har vi kommet til:  2837
# Nå har vi kommet til:  2838
# Nå har vi kommet til:  2839
# Nå har vi kommet til:  2840
# Nå har vi kommet til:  2841
# Nå har vi kommet til:  2842
# Nå har vi kommet til:  2843
# Nå har vi kommet til:  2844
# Nå har vi kommet til:  2845
# Nå har vi kommet til:  2846
# Nå har vi kommet til:  2847
# Nå har vi kommet til:  2848
# Nå har vi kommet til:  2849
# Nå har vi kommet til:  2850
# Nå har vi kommet til:  2851
# Nå har vi kommet til:  2852
# Nå har vi kommet til:  2853
# Nå har vi kommet til:  2854
# Nå har vi kommet til:  2855
# Nå har vi kommet til:  2856
# Nå har vi kommet til:  2857
# Nå har vi kommet til:  2858
# Nå har vi kommet til:  2859
# Nå har vi kommet til:  2860
# Nå har vi kommet til:  2861
# Nå har vi kommet til:  2862
# Nå har vi kommet til:  2863
# Nå har vi kommet til:  2864
# Nå har vi kommet til:  2865
# Nå har vi kommet til:  2866
# Nå har vi kommet til:  2867
# Nå har vi kommet til:  2868
# Nå har vi kommet til:  2869
# Nå har vi kommet til:  2870
# Nå har vi kommet til:  2871
# Nå har vi kommet til:  2872
# Nå har vi kommet til:  2873
# Nå har vi kommet til:  2874
# Nå har vi kommet til:  2875
# Nå har vi kommet til:  2876
# Nå har vi kommet til:  2877
# Nå har vi kommet til:  2878
# Nå har vi kommet til:  2879
# Nå har vi kommet til:  2880
# Nå har vi kommet til:  2881
# Nå har vi kommet til:  2882
# Nå har vi kommet til:  2883
# Nå har vi kommet til:  2884
# Nå har vi kommet til:  2885
# Nå har vi kommet til:  2886
# Nå har vi kommet til:  2887
# Nå har vi kommet til:  2888
# Nå har vi kommet til:  2889
# Nå har vi kommet til:  2890
# Nå har vi kommet til:  2891
# Nå har vi kommet til:  2892
# Nå har vi kommet til:  2893
# Nå har vi kommet til:  2894
# Nå har vi kommet til:  2895
# Nå har vi kommet til:  2896
# Nå har vi kommet til:  2897
# Nå har vi kommet til:  2898
# Nå har vi kommet til:  2899
# Nå har vi kommet til:  2900
# Nå har vi kommet til:  2901
# Nå har vi kommet til:  2902
# Nå har vi kommet til:  2903
# Nå har vi kommet til:  2904
# Nå har vi kommet til:  2905
# Nå har vi kommet til:  2906
# Nå har vi kommet til:  2907
# Nå har vi kommet til:  2908
# Nå har vi kommet til:  2909
# Nå har vi kommet til:  2910
# Nå har vi kommet til:  2911
# Nå har vi kommet til:  2912
# Nå har vi kommet til:  2913
# Nå har vi kommet til:  2914
# Nå har vi kommet til:  2915
# Nå har vi kommet til:  2916
# Nå har vi kommet til:  2917
# Nå har vi kommet til:  2918
# Nå har vi kommet til:  2919
# Nå har vi kommet til:  2920
# Nå har vi kommet til:  2921
# Nå har vi kommet til:  2922
# Nå har vi kommet til:  2923
# Nå har vi kommet til:  2924
# Nå har vi kommet til:  2925
# Nå har vi kommet til:  2926
# Nå har vi kommet til:  2927
# Nå har vi kommet til:  2928
# Nå har vi kommet til:  2929
# Nå har vi kommet til:  2930
# Nå har vi kommet til:  2931
# Nå har vi kommet til:  2932
# Nå har vi kommet til:  2933
# Nå har vi kommet til:  2934
# Nå har vi kommet til:  2935
# Nå har vi kommet til:  2936
# Nå har vi kommet til:  2937
# Nå har vi kommet til:  2938
# Nå har vi kommet til:  2939
# Nå har vi kommet til:  2940
# Nå har vi kommet til:  2941
# Nå har vi kommet til:  2942
# Nå har vi kommet til:  2943
# Nå har vi kommet til:  2944
# Nå har vi kommet til:  2945
# Nå har vi kommet til:  2946
# Nå har vi kommet til:  2947
# Nå har vi kommet til:  2948
# Nå har vi kommet til:  2949
# Nå har vi kommet til:  2950
# Nå har vi kommet til:  2951
# Nå har vi kommet til:  2952
# Nå har vi kommet til:  2953
# Nå har vi kommet til:  2954
# Nå har vi kommet til:  2955
# Nå har vi kommet til:  2956
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-1-9d91e5b41720> in <module>
#       3     teller(nummer + 1)
#       4
# ----> 5 teller()
#
# <ipython-input-1-9d91e5b41720> in teller(nummer)
#       1 def teller(nummer=0):
#       2     print("Nå har vi kommet til: ", nummer)
# ----> 3     teller(nummer + 1)
#       4
#       5 teller()
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-1-9d91e5b41720> in teller(nummer)
#       1 def teller(nummer=0):
#       2     print("Nå har vi kommet til: ", nummer)
# ----> 3     teller(nummer + 1)
#       4
#       5 teller()
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# Her ser vi en teller implementert rekursivt. Funksjonen begynner å telle fra null, siden det er standardverdien vi har gitt, før den kaller seg selv på nytt, men denne gangen med økt verdi. Vi kan også lage en funksjon med samme funksjonalitet iterativt, ved hjelp av løkker. Funksjonen under vil gjøre akkurat det samme som vår rekursive teller.

# %%
def teller2():
    nummer = 0
    while True:
        print("Nå har vi kommet til: ", nummer)
        nummer += 1
        
teller()

# %% [markdown]
# Men, som du kanskje har lagt merke til, har vår rekursive funksjon en stor svakhet, den slutter aldri. Funksjonen vår vil fortsette å telle helt til vi får en RecursionError, hvor vi får beskjed om at maksimum rekursjons dybde er nådd. Vi kan se på det som at hver gang vi kaller en rekursiv funksjon graver vi oss lengre ned i et hull, og Python setter en grense for hvor langt ned vi kan grave, forhåpentligvis ønsker vi å komme oss opp igjen av hullet også, men det ser vi på litt senere. Først la oss fokusere på at funksjonen vår aldri avslutter.
#
# Rekursive funksjoner trenger det vi kaller vi et **grunntilfelle**, et sted hvor koden innser at det er på tide å slutte. La oss prøve å endre telleren slik at den slutter å telle når den kommer til 10.

# %%
def teller(nummer=0):
    print("Nå har vi kommet til: ", nummer)
    if(nummer<10):
        teller(nummer + 1)
        
teller()
# Out:
# Nå har vi kommet til:  0
# Nå har vi kommet til:  1
# Nå har vi kommet til:  2
# Nå har vi kommet til:  3
# Nå har vi kommet til:  4
# Nå har vi kommet til:  5
# Nå har vi kommet til:  6
# Nå har vi kommet til:  7
# Nå har vi kommet til:  8
# Nå har vi kommet til:  9
# Nå har vi kommet til:  10

# %% [markdown]
# Som du nå selv kan teste, vil funksjonen vår telle til 10, før den gir seg. Vi har et tilfelle hvor funksjonen finner ut at den skal stoppe, og vi slipper at Python skal gi oss en streng beskjed om at vi må slutte å kalle funksjonen vår. Tidligere nevnte vi også ambisjoner om å klatre opp igjen fra hullet vi har laget oss, så la oss først ta en kikk på en klassiskt bruksområde når det kommer til rekursjon, nemlig hvordan vi kan regne fakultet:

# %%
def fakultet(tall):
    if tall==0:
        return 1
    else:
        return tall*fakultet(tall-1)

fakultet(5)
# Out:
# 120

# %% [markdown]
# Her baserer vi oss på grunntilfellet hvor null fakultet er lik 1. Ellers vet vi at fakultet av et tall er lik tallet selv gange fakultet av tallet selv minus en. Altså f.eks. er 5! = 5 * 4!. Det kan vi enkelt løse rekursivt, som vi allerede har gjort. Det som er nytt for dette eksempelet er at vi faktisk benytter oss av resultatet av funksjonskallene våre. Når vi kaller funksjonen med tallet 3 vil følgende skje:
#
# > Vi prøver å regne ut 3! men siden vi trenger 2! kaller vi funksjonen på nytt.
# Vi prøver å regne ut 2! men siden vi trenger 1! kaller vi funksjonen på nytt.
# Vi prøver å regne ut 1! men siden vi trenger 0! kaller vi funksjonen på nytt.
# Vi prøver å regne ut 0!, det vet vi er 1.
# Vi benytter oss av resultatet over, finner ut at 1! er 1.
# Vi benytter oss av resultatet over, finner ut at 2! er 2.
# Vi benytter oss av resultatet over, finner ut at 3! er 6.
#
# Hvis vi fortsetter å tenke på grave-eksempelet kan vi se at vi over har to faser, en hvor vi kaller funksjonen på nytt og graver oss ned, før vi omsider finner bunnen og klatrer opp igjen. Ved å trykke [her](http://pythontutor.com/visualize.html#code=def%20fakultet%28tall%29%3A%0A%20%20%20%20if%20tall%3D%3D0%3A%0A%20%20%20%20%20%20%20%20return%201%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20return%20tall*fakultet%28tall-1%29%0A%0Afakultet%285%29&cumulative=false&curInstr=26&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false) kan du få visualisert hvordan vi regner ut fakultet av fem steg for steg.

# %% [markdown]
# La oss ta en kikk på en nytt eksempel men denne gangen skal vi bruke en liste, hvor vi ønsker å summere alle elementene rekursivt. Som nevnt introduksjonsmessig er rekursivitet brukt mye i sorteringsalgoritmer, og selv om det ofte kan virke som om det vi gjør rekursivt alltid kan gjøres iterativt, er ikke det alltid tilfelle. Rekursjon er derfor viktig å forstå, selv om det også er vanskelig.

# %%
def liste_sum(liste):
    if(len(liste)==1):
        return liste[0] #dersom listen kun har et element er summen vår bare det ene elementet
    else:
        return liste[0]+liste_sum(liste[1:]) #ellers tar vi det første elementet og legger til summen av resten av lista
    
liste_sum([1,2,3])
# Out:
# 6

# %% [markdown]
# Det er kanskje ikke så mye nytt her med unntak av at vi denne gangen fokuserer på en liste, men la oss også nå se steg for seg hva som skjer.
#
# > Vi vil ha summen av [1,2,3], vi vet dette er 1 + summen av [2,3], vi kaller funksjonen på nytt
# Vi vil ha summen av [2,3], vi vet dette er 2 + summen av [3], vi kaller funksjonen på nytt
# Vi vet at summen av [3] er 3, så vi gir verdien til funksjons-kallet over.
# Siden summen av [3] var 3, er summen [2,3] = 2 + 3 = 5
# Siden summen av [2,3] var 5, er summen av [1,2,3] = 1 + 5 = 6.
#
# Det ligner mye på det vi gjorde når vi implementerte fakultet, vi jobber oss nedover, når bunnen, og går tilbake opp. Trykk [her](http://pythontutor.com/visualize.html#code=def%20liste_sum%28liste%29%3A%0A%20%20%20%20if%28len%28liste%29%3D%3D1%29%3A%0A%20%20%20%20%20%20%20%20return%20liste%5B0%5D%20%23dersom%20listen%20kun%20har%20et%20element%20er%20summen%20v%C3%A5r%20bare%20det%20ene%20elementet%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20return%20liste%5B0%5D%2Bliste_sum%28liste%5B1%3A%5D%29%20%23ellers%20tar%20vi%20det%20f%C3%B8rste%20elementet%20og%20legger%20til%20summen%20av%20resten%20av%20lista%0A%20%20%20%20%0Aliste_sum%28%5B1,2,3%5D%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false) for en visualisering.
#
# Nå har du fått en rask innføring i hvordan programmere rekursivt. Hvis du vil ha en litt annen innføring i temaet kan du sjekke ut [denne linken](https://realpython.com/python-thinking-recursively/).

# %% [markdown]
# ### a) Rekursiv sum

# %% [markdown]
# Skriv en funksjon `recursive_sum(n)` som tar inn et heltall n og regner summen av  1+2+...+n ved hjelp av rekursjon.
#
# **Eksempel på kjøring:**
# ```python
# >>>print(recursive_sum(53))
# 1431
# ```

# %%
def recursive_sum(n):
    if n==0:
        return 0
    sum=n+recursive_sum(n-1)
    return sum

print(recursive_sum(53))
# Out:
# 1431

# %% [markdown]
# #### Hint

# %% [markdown]
# Se på eksempelet med fakultet i tutorialen.

# %% [markdown]
# ### b) Merge sum

# %% [markdown]
# Skriv en funksjon `merge_sum(liste)` som summerer alle elementene i en liste men på en litt annen måte enn i tutorialen.
#
# * Anta et partall antall elementer i lista.
# * Når du skal summere elementene skal det gjøres ved å dele lista i to, og så addere summen av hver halvdel av listen.

# %%
def merge_sum(list):
    if len(list)==1:
        return list[0]
    else:
        H = len(list)//2
        sum = merge_sum(list[:H]) + merge_sum(list[H:])
    return sum

merge_sum([1,2,3,4,5])
# Out:
# 15

# %% [markdown]
# #### Hint

# %% [markdown]
# Tenk på grunntilfellet og hva funksjonen skal returnere.
# Hvor skal vi dele lista?

# %% [markdown]
# ### c) Minste element

# %% [markdown]
# Skriv en rekursiv funksjon `find_smallest_element(numbers)` som tar inn en liste numbers med heltall og finner det minste elementet i listen.
# *Merk: Du kan ikke bruke innebygde funksjoner i Python som min(liste), for å løse denne oppgaven.*
#
# ```python
# >>>print(find_smallest_element([5,3,2,6]))
# 2
# ```

# %%
def find_smallest_element(numbers):
    if len(numbers)==2:
        if numbers[0]<numbers[1]:
            return numbers[0]
        else:
            return numbers[1]
    else:
        half=len(numbers)//2
        if find_smallest_element(numbers[:half])>find_smallest_element(numbers[half:]):
            return find_smallest_element(numbers[half:])
        else:
            return find_smallest_element(numbers[:half])
    
print(find_smallest_element([2,3,1,5]))
# Out:
# 1

# %% [markdown]
# #### Hint

# %% [markdown]
# Ta en kikk på eksempelet med listesum i tutorialen. Her vil du kunne buke en lignende framgangsmåte, men med en litt annen logikk.

# %% [markdown]
# ### d) Binærsøk

# %% [markdown]
# Skriv en rekursiv funksjon `binary_search(numbers, element)` som tar inn en sortert liste **numbers** med heltall og et heltall **element** og returnerer posisjonen(indeksen) til elementet dersom det finnes i listen. Hvis det ikke finnes skal funksjonen returnere minus uendelig (**-float('inf')**). Dette skal du gjøre ved å benytte deg av [binærsøk-algoritmen](https://en.wikipedia.org/wiki/Binary_search_algorithm).
#
# Du kan også implementere funksjonen `binary_search(numbers, element, minimum, maximum)`, altså samme funksjon, med samme funksjonalitet, men med parameterene **minimum** og **maximum**, som vi kan bruke til å angi indeksene vi søker på i lista.
#
# *Merk: I denne oppgaven er det ikke lov til å bruke innebygde funksjoner i Python som liste.index(element).*
#
# **BONUS**: Hvis listen numbers inneholder n elementer, hvor mange funksjonskall vil binærsøk-algoritmen i worst case trenge for å finne posisjonen til elementet i listen? (eller at elementet ikke er i listen)

# %%
def binary_search(numbers, element):

# %% [markdown]
# #### Hint

# %% [markdown]
# Tenk på midterste element.
